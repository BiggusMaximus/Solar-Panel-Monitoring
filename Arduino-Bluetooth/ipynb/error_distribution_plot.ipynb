# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../docs/error_voltage_all.csv')
df
# Out:
#      0.5v         3v        6v        9v       12v       15v       18v  \
# 0     2.0  12.000000  0.333333  0.444444  0.083333  0.266667  0.388889
# 1     8.0   0.666667  0.333333  0.666667  1.333333  0.266667  0.222222
# 2     2.0   3.333333  0.333333  0.222222  0.333333  0.066667  0.111111
# 3     8.0   1.666667  0.166667  0.888889  0.083333  0.066667  1.055556
# 4    12.0   1.666667  0.500000  1.444444  0.083333  1.066667  0.111111
# ..    ...        ...       ...       ...       ...       ...       ...
# 995  12.0   2.666667  1.166667  0.444444  0.083333  0.066667  0.222222
# 996  32.0   2.333333  0.833333  0.444444  0.083333  0.066667  1.055556
# 997   8.0   1.666667  1.666667  0.444444  0.333333  0.066667  0.388889
# 998  26.0   0.000000  1.166667  0.444444  0.083333  0.066667  0.111111
# 999   8.0   0.666667  0.333333  0.222222  0.083333  0.066667  0.222222
#
#           21v
# 0    0.571429
# 1    0.571429
# 2    0.428571
# 3    1.047619
# 4    0.809524
# ..        ...
# 995  0.571429
# 996  0.428571
# 997  0.190476
# 998  0.428571
# 999  0.190476
#
# [1000 rows x 8 columns]

# %%
f = plt.figure()
f.set_figwidth(5)
f.set_figheight(10)

for i in df.columns:
    plt.plot(df.index, df[i].std()/np.sqrt(df.index), label=i)
    
plt.axhline(y=1, linestyle="--", label="1%")
plt.xlabel("Sample Sizes")
plt.ylabel("Voltage Error (%)")
plt.legend()
plt.grid()
plt.savefig('../docs/error_std_width.png')
plt.show()

# %%
for i in df.columns:
    x = (df[i].std() /1)**2
    print(f"{i} 1% when sample sizes : {x}")
# Out:
# 0.5v 1% when sample sizes : 45.2089049049049
# 3v 1% when sample sizes : 2.644741519297075
# 6v 1% when sample sizes : 0.4098829662996346
# 9v 1% when sample sizes : 0.18204233863493277
# 12v 1% when sample sizes : 0.13670330747414147
# 15v 1% when sample sizes : 0.16524965409854397
# 18v 1% when sample sizes : 0.10375066115498269
# 21v 1% when sample sizes : 0.09747007551769447
