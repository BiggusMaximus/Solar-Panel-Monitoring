# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import sem

# %%
df = pd.read_csv('../docs 2nd Approach/remove_outlier_chauvenet.csv')
df
# Out:
#       index voltage     value
# 0       454    0.5v -2.000000
# 1       455    0.5v -2.000000
# 2       456    0.5v -2.000000
# 3       457    0.5v -2.000000
# 4       458    0.5v -2.000000
# ...     ...     ...       ...
# 8152   8995   24.5v  1.959184
# 8153   8996   24.5v  1.959184
# 8154   8997   24.5v  1.959184
# 8155   8998   24.5v  1.959184
# 8156   8999   24.5v  1.959184
#
# [8157 rows x 3 columns]

# %%
f = plt.figure()
f.set_figwidth(12)
f.set_figheight(8)


plt.plot(df.index, df['value'].std()/np.sqrt(df.index))
    
plt.xlabel("Sample Sizes")
plt.ylabel("Voltage Error (%)")
plt.legend()
plt.grid()
plt.savefig('../docs/error_std_width.png')
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
